# %%
# If you have any issues, try to use Python 3.7 

# !pip install numpy==1.19.2
# !pip install pandas==1.3.3
# !pip install scipy==1.6.2
# !pip install tensorflow==2.4.0
# !pip install tensorflow-probability==0.11.0
# !pip install scikit-learn==0.24.1
# !pip install statsmodels==0.12.2
# !pip install ta
# !pip install datetime
# !pip install yfinance
# !pip install MetaTrader5
# !pip install TA-Lib
# Out:
# Collecting numpy==1.19.2
#   Downloading numpy-1.19.2.zip (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 15.1 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   WARNING: Missing build requirements in pyproject.toml for numpy==1.19.2 from https://files.pythonhosted.org/packages/bf/e8/15aea783ea72e2d4e51e3ec365e8dc4a1a32c9e5eb3a6d695b0d58e67cdd/numpy-1.19.2.zip.
#   WARNING: The project does not specify a build backend, and pip cannot fall back to setuptools without 'setuptools>=40.8.0'.
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [45 lines of output]
#       Running from numpy source directory.
#       setup.py:470: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates
#         run_build = parse_setuppy_commands()
#       Cythonizing sources
#       Processing numpy/random/_bounded_integers.pxd.in
#       Processing numpy/random/_philox.pyx
#       Traceback (most recent call last):
#         File "/private/var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/pip-install-p7yhygeo/numpy_df7aefa46d1842fd9cb677f641ab00d1/tools/cythonize.py", line 59, in process_pyx
#           from Cython.Compiler.Version import version as cython_version
#       ModuleNotFoundError: No module named 'Cython'
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "/private/var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/pip-install-p7yhygeo/numpy_df7aefa46d1842fd9cb677f641ab00d1/tools/cythonize.py", line 235, in <module>
#           main()
#         File "/private/var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/pip-install-p7yhygeo/numpy_df7aefa46d1842fd9cb677f641ab00d1/tools/cythonize.py", line 231, in main
#           find_process_files(root_dir)
#         File "/private/var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/pip-install-p7yhygeo/numpy_df7aefa46d1842fd9cb677f641ab00d1/tools/cythonize.py", line 222, in find_process_files
#           process(root_dir, fromfile, tofile, function, hash_db)
#         File "/private/var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/pip-install-p7yhygeo/numpy_df7aefa46d1842fd9cb677f641ab00d1/tools/cythonize.py", line 188, in process
#           processor_function(fromfile, tofile)
#         File "/private/var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/pip-install-p7yhygeo/numpy_df7aefa46d1842fd9cb677f641ab00d1/tools/cythonize.py", line 64, in process_pyx
#           raise OSError('Cython needs to be installed in Python as a module')
#       OSError: Cython needs to be installed in Python as a module
#       Traceback (most recent call last):
#         File "/Applications/miniconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/Applications/miniconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "/Applications/miniconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 149, in prepare_metadata_for_build_wheel
#           return hook(metadata_directory, config_settings)
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 156, in prepare_metadata_for_build_wheel
#           self.run_setup()
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 236, in run_setup
#           super(_BuildMetaLegacyBackend,
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 142, in run_setup
#           exec(compile(code, __file__, 'exec'), locals())
#         File "setup.py", line 499, in <module>
#           setup_package()
#         File "setup.py", line 479, in setup_package
#           generate_cython()
#         File "setup.py", line 274, in generate_cython
#           raise RuntimeError("Running cythonize failed!")
#       RuntimeError: Running cythonize failed!
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting pandas==1.3.3
#   Using cached pandas-1.3.3.tar.gz (4.7 MB)
#   Installing build dependencies ... done
#   WARNING: Missing build requirements in pyproject.toml for pandas==1.3.3 from https://files.pythonhosted.org/packages/71/65/3ab03ef46613e66880dba5b2c2cb5836938f0219389a11c10cfdc617e836/pandas-1.3.3.tar.gz.
#   WARNING: The project does not specify a build backend, and pip cannot fall back to setuptools without 'setuptools>=40.8.0'.
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       Traceback (most recent call last):
#         File "/Applications/miniconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/Applications/miniconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "/Applications/miniconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 146, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=['wheel'])
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 127, in _get_build_requires
#           self.run_setup()
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 236, in run_setup
#           super(_BuildMetaLegacyBackend,
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 142, in run_setup
#           exec(compile(code, __file__, 'exec'), locals())
#         File "setup.py", line 18, in <module>
#           import numpy
#       ModuleNotFoundError: No module named 'numpy'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Ignored the following versions that require a different python version: 1.6.2 Requires-Python >=3.7,<3.10; 1.6.3 Requires-Python >=3.7,<3.10; 1.7.0 Requires-Python >=3.7,<3.10; 1.7.1 Requires-Python >=3.7,<3.10; 1.7.2 Requires-Python >=3.7,<3.11; 1.7.3 Requires-Python >=3.7,<3.11; 1.8.0 Requires-Python >=3.8,<3.11; 1.8.0rc1 Requires-Python >=3.8,<3.11; 1.8.0rc2 Requires-Python >=3.8,<3.11; 1.8.0rc3 Requires-Python >=3.8,<3.11; 1.8.0rc4 Requires-Python >=3.8,<3.11; 1.8.1 Requires-Python >=3.8,<3.11
# ERROR: Could not find a version that satisfies the requirement scipy==1.6.2 (from versions: 0.8.0, 0.9.0, 0.10.0, 0.10.1, 0.11.0, 0.12.0, 0.12.1, 0.13.0, 0.13.1, 0.13.2, 0.13.3, 0.14.0, 0.14.1, 0.15.0, 0.15.1, 0.16.0, 0.16.1, 0.17.0, 0.17.1, 0.18.0, 0.18.1, 0.19.0, 0.19.1, 1.0.0, 1.0.1, 1.1.0, 1.2.0, 1.2.1, 1.2.2, 1.2.3, 1.3.0, 1.3.1, 1.3.2, 1.3.3, 1.4.0, 1.4.1, 1.5.0, 1.5.1, 1.5.2, 1.5.3, 1.5.4, 1.6.0, 1.6.1, 1.9.0rc1, 1.9.0rc2, 1.9.0rc3, 1.9.0, 1.9.1, 1.9.2, 1.9.3, 1.10.0rc1, 1.10.0rc2, 1.10.0, 1.10.1, 1.11.0rc1, 1.11.0rc2, 1.11.0, 1.11.1, 1.11.2, 1.11.3, 1.11.4)
# ERROR: No matching distribution found for scipy==1.6.2
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.4.0 (from versions: 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0)
# ERROR: No matching distribution found for tensorflow==2.4.0
# Collecting tensorflow-probability==0.11.0
#   Downloading tensorflow_probability-0.11.0-py2.py3-none-any.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 10.0 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: six>=1.10.0 in /Applications/miniconda3/lib/python3.11/site-packages (from tensorflow-probability==0.11.0) (1.16.0)
# Requirement already satisfied: numpy>=1.13.3 in /Applications/miniconda3/lib/python3.11/site-packages (from tensorflow-probability==0.11.0) (1.26.1)
# Requirement already satisfied: decorator in /Applications/miniconda3/lib/python3.11/site-packages (from tensorflow-probability==0.11.0) (5.1.1)
# Collecting cloudpickle==1.3 (from tensorflow-probability==0.11.0)
#   Downloading cloudpickle-1.3.0-py2.py3-none-any.whl (26 kB)
# Collecting gast>=0.3.2 (from tensorflow-probability==0.11.0)
#   Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting dm-tree (from tensorflow-probability==0.11.0)
#   Downloading dm_tree-0.1.8-cp311-cp311-macosx_11_0_arm64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 9.3 MB/s eta 0:00:00
# Installing collected packages: dm-tree, cloudpickle, gast, tensorflow-probability
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.0.0
#     Uninstalling cloudpickle-3.0.0:
#       Successfully uninstalled cloudpickle-3.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pycaret 3.1.0 requires deprecation>=2.1.0, which is not installed.
# pycaret 3.1.0 requires kaleido>=0.2.1, which is not installed.
# pycaret 3.1.0 requires lightgbm>=3.0.0, which is not installed.
# pycaret 3.1.0 requires numba>=0.55.0, which is not installed.
# pycaret 3.1.0 requires plotly-resampler>=0.8.3.1, which is not installed.
# pycaret 3.1.0 requires pmdarima!=1.8.1,<3.0.0,>=1.8.0, which is not installed.
# pycaret 3.1.0 requires pyod>=1.0.8, which is not installed.
# pycaret 3.1.0 requires schemdraw==0.15, which is not installed.
# pycaret 3.1.0 requires sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1, which is not installed.
# pycaret 3.1.0 requires tbats>=1.1.3, which is not installed.
# pycaret 3.1.0 requires wurlitzer; platform_system != "Windows", which is not installed.
# pycaret 3.1.0 requires numpy<1.24,>=1.21, but you have numpy 1.26.1 which is incompatible.
# pycaret 3.1.0 requires pandas<2.0.0,>=1.3.0, but you have pandas 2.1.2 which is incompatible.
# pycaret 3.1.0 requires scikit-learn<1.3.0,>=1.0, but you have scikit-learn 1.3.2 which is incompatible.
# pycaret 3.1.0 requires scipy~=1.10.1, but you have scipy 1.11.3 which is incompatible.
# Successfully installed cloudpickle-1.3.0 dm-tree-0.1.8 gast-0.5.4 tensorflow-probability-0.11.0
# Collecting scikit-learn==0.24.1
#   Downloading scikit-learn-0.24.1.tar.gz (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 17.7 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   WARNING: Missing build requirements in pyproject.toml for scikit-learn==0.24.1 from https://files.pythonhosted.org/packages/f4/7b/d415b0c89babf23dcd8ee631015f043e2d76795edd9c7359d6e63257464b/scikit-learn-0.24.1.tar.gz.
#   WARNING: The project does not specify a build backend, and pip cannot fall back to setuptools without 'setuptools>=40.8.0'.
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [28 lines of output]
#       Partial import of sklearn during the build process.
#       running dist_info
#       creating /private/var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/pip-modern-metadata-1h6d8blf/scikit_learn.egg-info
#       writing /private/var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/pip-modern-metadata-1h6d8blf/scikit_learn.egg-info/PKG-INFO
#       writing dependency_links to /private/var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/pip-modern-metadata-1h6d8blf/scikit_learn.egg-info/dependency_links.txt
#       writing requirements to /private/var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/pip-modern-metadata-1h6d8blf/scikit_learn.egg-info/requires.txt
#       writing top-level names to /private/var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/pip-modern-metadata-1h6d8blf/scikit_learn.egg-info/top_level.txt
#       writing manifest file '/private/var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/pip-modern-metadata-1h6d8blf/scikit_learn.egg-info/SOURCES.txt'
#       reading manifest file '/private/var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/pip-modern-metadata-1h6d8blf/scikit_learn.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no previously-included files matching '*' found under directory 'asv_benchmarks'
#       warning: no previously-included files matching '*' found under directory 'benchmarks'
#       warning: no previously-included files matching '*' found under directory 'build_tools'
#       warning: no previously-included files matching '*' found under directory 'maint_tools'
#       warning: no previously-included files matching '*' found under directory 'benchmarks'
#       warning: no previously-included files matching '*' found under directory '.binder'
#       warning: no previously-included files matching '*' found under directory '.circleci'
#       warning: no previously-included files found matching '.codecov.yml'
#       warning: no previously-included files found matching '.mailmap'
#       warning: no previously-included files found matching '.pre-commit-config.yaml'
#       warning: no previously-included files found matching 'azure-pipelines.yml'
#       warning: no previously-included files found matching 'lgtm.yml'
#       warning: no previously-included files found matching 'CODE_OF_CONDUCT.md'
#       warning: no previously-included files found matching 'CONTRIBUTING.md'
#       warning: no previously-included files found matching 'PULL_REQUEST_TEMPLATE.md'
#       writing manifest file '/private/var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/pip-modern-metadata-1h6d8blf/scikit_learn.egg-info/SOURCES.txt'
#       creating '/private/var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/pip-modern-metadata-1h6d8blf/scikit_learn.dist-info'
#       error: invalid command 'bdist_wheel'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting statsmodels==0.12.2
#   Downloading statsmodels-0.12.2.tar.gz (17.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 25.1 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   WARNING: Missing build requirements in pyproject.toml for statsmodels==0.12.2 from https://files.pythonhosted.org/packages/10/26/0fd61f95667e56fd597ecca715dff3623ed1122b6f895ed2b4dfb54afc04/statsmodels-0.12.2.tar.gz.
#   WARNING: The project does not specify a build backend, and pip cannot fall back to setuptools without 'setuptools>=40.8.0'.
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [36 lines of output]
#       Traceback (most recent call last):
#         File "/Applications/miniconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/Applications/miniconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "/Applications/miniconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 149, in prepare_metadata_for_build_wheel
#           return hook(metadata_directory, config_settings)
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 156, in prepare_metadata_for_build_wheel
#           self.run_setup()
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 236, in run_setup
#           super(_BuildMetaLegacyBackend,
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/build_meta.py", line 142, in run_setup
#           exec(compile(code, __file__, 'exec'), locals())
#         File "setup.py", line 337, in <module>
#           setup(name=DISTNAME,
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/__init__.py", line 144, in setup
#           _install_setup_requires(attrs)
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/__init__.py", line 139, in _install_setup_requires
#           dist.fetch_build_eggs(dist.setup_requires)
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/dist.py", line 716, in fetch_build_eggs
#           resolved_dists = pkg_resources.working_set.resolve(
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pkg_resources/__init__.py", line 780, in resolve
#           dist = best[req.key] = env.best_match(
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pkg_resources/__init__.py", line 1065, in best_match
#           return self.obtain(req, installer)
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pkg_resources/__init__.py", line 1077, in obtain
#           return installer(requirement)
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/dist.py", line 786, in fetch_build_egg
#           return cmd.easy_install(req)
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/command/easy_install.py", line 679, in easy_install
#           return self.install_item(spec, dist.location, tmpdir, deps)
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/command/easy_install.py", line 705, in install_item
#           dists = self.install_eggs(spec, download, tmpdir)
#         File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/setuptools/command/easy_install.py", line 874, in install_eggs
#           raise DistutilsError(
#       distutils.errors.DistutilsError: Couldn't find a setup script in /var/folders/bw/bfxh3_fn16n8wrfjlq7v6w3c0000gn/T/easy_install-dvs_340i/scipy-1.11.4.tar.gz
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Applications/miniconda3/lib/python3.11/site-packages (from ta) (1.26.1)
# Requirement already satisfied: pandas in /Applications/miniconda3/lib/python3.11/site-packages (from ta) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Applications/miniconda3/lib/python3.11/site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Applications/miniconda3/lib/python3.11/site-packages (from pandas->ta) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Applications/miniconda3/lib/python3.11/site-packages (from pandas->ta) (2023.3)
# Requirement already satisfied: six>=1.5 in /Applications/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->ta) (1.16.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [8 lines of output]
#       /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/distutils/dist.py:274: UserWarning: Unknown distribution option: 'license_files'
#         warnings.warn(msg)
#       usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#          or: setup.py --help [cmd1 cmd2 ...]
#          or: setup.py --help-commands
#          or: setup.py cmd --help
#
#       error: invalid command 'bdist_wheel'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for ta
#   Running setup.py clean for ta
# Failed to build ta
# ERROR: Could not build wheels for ta, which is required to install pyproject.toml-based projects
# Collecting datetime
#   Obtaining dependency information for datetime from https://files.pythonhosted.org/packages/d3/63/dced85cf2970b5d363e501a10aa051e71caea3ad10a60b7a57794f43a4b8/DateTime-5.3-py3-none-any.whl.metadata
#   Downloading DateTime-5.3-py3-none-any.whl.metadata (33 kB)
# Collecting zope.interface (from datetime)
#   Obtaining dependency information for zope.interface from https://files.pythonhosted.org/packages/3e/1f/43557bb2b6e8537002a5a26af9b899171e26ddfcdf17a00ff729b00c036b/zope.interface-6.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading zope.interface-6.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /Applications/miniconda3/lib/python3.11/site-packages (from datetime) (2023.3.post1)
# Requirement already satisfied: setuptools in /Applications/miniconda3/lib/python3.11/site-packages (from zope.interface->datetime) (68.0.0)
# Downloading DateTime-5.3-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 3.3 MB/s eta 0:00:00
# Downloading zope.interface-6.1-cp311-cp311-macosx_11_0_arm64.whl (202 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.5/202.5 kB 3.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: zope.interface, datetime
# Successfully installed datetime-5.3 zope.interface-6.1
# Requirement already satisfied: yfinance in /Applications/miniconda3/lib/python3.11/site-packages (0.2.31)
# Requirement already satisfied: pandas>=1.3.0 in /Applications/miniconda3/lib/python3.11/site-packages (from yfinance) (2.1.2)
# Requirement already satisfied: numpy>=1.16.5 in /Applications/miniconda3/lib/python3.11/site-packages (from yfinance) (1.26.1)
# Requirement already satisfied: requests>=2.31 in /Applications/miniconda3/lib/python3.11/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Applications/miniconda3/lib/python3.11/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Applications/miniconda3/lib/python3.11/site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /Applications/miniconda3/lib/python3.11/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /Applications/miniconda3/lib/python3.11/site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /Applications/miniconda3/lib/python3.11/site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: peewee>=3.16.2 in /Applications/miniconda3/lib/python3.11/site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Applications/miniconda3/lib/python3.11/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in /Applications/miniconda3/lib/python3.11/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /Applications/miniconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /Applications/miniconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Applications/miniconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Applications/miniconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Applications/miniconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Applications/miniconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Applications/miniconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Applications/miniconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/miniconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2023.7.22)
# ERROR: Could not find a version that satisfies the requirement MetaTrader5 (from versions: none)
# ERROR: No matching distribution found for MetaTrader5
# Collecting TA-Lib
#   Downloading TA-Lib-0.4.28.tar.gz (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.1/357.1 kB 3.0 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... -
